# %%
import os
import warnings
warnings.filterwarnings('ignore')

import scanpy as sc
import numpy as np
import pandas as pd

# %%
adata = sc.read_h5ad('../../output/annotated_subset_with_latent.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 51879 × 36579
# ...

# %%
adata.obs.patient_id.value_counts()
# Out:
# patient_id
# S1    13300
# S4    11314
# S2     8646
# S5     7640
# S6     6474
# S3     4505
# Name: count, dtype: int64

# %%
bdata = adata[adata.obs.patient_id == "S1"].copy()
bdata
# Out:
# AnnData object with n_obs × n_vars = 13300 × 36579
# ...

# %%
sc.pl.umap(bdata, color = ['cell_type', 'tissue'], wspace=0.5)
